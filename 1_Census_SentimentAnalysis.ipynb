# %% [markdown]
# Purpose of the script:
# Basic Sentiment Analysis of answers to questions 1, 4, 5, and 8 in the Census Consultations.

# %% [markdown]
# ### 1. Imports and Set Up

# %%
import os
import pandas as pd
import numpy as np

# %%
# Set up working directory

cwd = os.chdir('/Users/alessia/Documents/DataScience/NLP_Project/Data')

# %% [markdown]
# ### 2. Get Data

# %%
# Read in data (note header is spread over two rows)

cons0_df = pd.read_excel("The CensusCopy.xlsx",  header=None)

# %% [markdown]
# ### 3. Transform Data
#
# 3.1. Combine the headers - now in two rows - into one unique row

# %%
# Explore data

cons0_df.head(3)
# Out:
#               0             1                    2                    3   \
# 0  Respondent ID  Collector ID           Start Date             End Date
# 1            NaN           NaN                  NaN                  NaN
# 2     3001215611      45151668  2014-01-05 02:42:21  2014-01-05 02:44:13
#
#                4              5           6          7              8   \
# 0      IP Address  Email Address  First Name  Last Name  Custom Data 1
# 1             NaN            NaN         NaN        NaN            NaN
# 2  49.224.154.245            NaN         NaN        NaN            NaN
#
#                                                   9   \
# 0  Are you responding on behalf of an organisatio...
# 1                                           Response
# 2                                                NaN
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
#
#                                                   40  \
# 0  2. Please specify any significant uses of popu...
# 1                                Open-Ended Response
# 2                                                NaN
#
#                                                   41  \
# 0  3. Please specify any significant additional b...
# 1                                Open-Ended Response
# 2                                                NaN
#
#                                                   42  \
# 0  4. What would the impact be if the most detail...
# 1                                           Response
# 2                                                NaN
#
#                                                   43  \
# 0                                                NaN
# 1  <b>4. 1. If you have answered high or medium i...
# 2                                                NaN
#
#                                                   44  \
# 0  5. What would the additional benefit be if mor...
# 1                                           Response
# 2                                                NaN
#
#                                                   45  \
# 0                                                NaN
# 1  <b>5. 1. If you have answered high or medium i...
# 2                                                NaN
#
#                                                   46  \
# 0  6. Please specify any significant uses of cens...
# 1                                Open-Ended Response
# 2                                                NaN
#
#                                                   47  \
# 0  7. What advantages or opportunities for geneal...
# 1                                Open-Ended Response
# 2                                                NaN
#
#                                                   48  \
# 0  8. What are your views of the risks of each ce...
# 1                                Open-Ended Response
# 2                                                NaN
#
#                                                   49
# 0  9. Are there any other issues that you believe...
# 1                                Open-Ended Response
# 2                                                NaN
#
# [3 rows x 50 columns]

# %%
print( cons0_df.values.shape )  # (1110, 50)
# Out:
# (1110, 50)

# %%
# Row 1: 

# propagate non-null values forward, so that if a cell contains a NaN, the cell gets the value of the cell before

row1 = cons0_df.ffill(1).values[:1, :]

# %%
# Checks
print(row1.ndim)
print(row1.shape)          # (1,50)
print(row1[:, [0, -1]])    # print first and last values
# Out:
# 2
# (1, 50)
# [['Respondent ID'
#   '9. Are there any other issues that you believe we should be taking into account?']]

# %%
# Row 2: 

# replace NaN with empty cell (otherwise they will be float object, we want a list of only strings)

row2 = cons0_df.fillna('').values[1:2, :]

# %%
#Checks
print(type(row2))
print(row2.ndim)
print(row2.shape)  # (1,50)
print(row2[:, [0, -1]])
# Out:
# <class 'numpy.ndarray'>
# 2
# (1, 50)
# [['' 'Open-Ended Response']]

# %%
# Combine row1 and row2 into one unique "header" row

header_row = row1 + row2

# %% [markdown]
# 3.2. Reconstruct the dataframe

# %%
# Save header_row as DataFrame
header_row_df = pd.DataFrame(header_row)

# Save all other rows as dataframe
data_values_df = pd.DataFrame(cons0_df.values[2:, :])

# %%
# Append the two together
cons1_df = header_row_df.append(data_values_df,  
                                ignore_index=True
                               )

# %%
# Make first row as header
cons1_df.columns = cons1_df.iloc[0]

# Drop the first row (which is now redundant)
cons1_df = cons1_df.drop(0)

# %%
# Reset index 
cons1_df = cons1_df.reset_index(drop=True)

# %%
# Checks
print(cons1_df.columns.values[:8])
print(cons1_df.columns.values[-1:])
# Out:
# ['Respondent ID' 'Collector ID' 'Start Date' 'End Date' 'IP Address'
#  'Email Address' 'First Name' 'Last Name']
# [ '9. Are there any other issues that you believe we should be taking into account?Open-Ended Response']

# %% [markdown]
# ### 4. Sentiment Analysis of questions 1, 4, 5 and 8

# %% [markdown]
# 4.1. Define function to calculate polarity score for the answers in our dataset

# %%
# Define function to calculate polarity score for the answers in our dataset

def get_sentiment_score(data, col_ind) :
    """ Return list of polarity scores for values in the specified column """
    
    # import key modules
    from nltk.sentiment.vader import SentimentIntensityAnalyzer
    analyser = SentimentIntensityAnalyzer()
    
    # empty list collector of scores
    sentiment_bag = []
    
    for answer in data.iloc[:, col_ind] :
        
        # no answer was provided, return NA
        if pd.isnull(answer) : 
            sentiment_bag.append(np.nan)
            
        else :
            sentiment_bag.append(analyser.polarity_scores(answer)['compound'])
    
    return(sentiment_bag)

# %% [markdown]
# 4.2. Calculate Sentiment Score for answers to relevant questions: Q1, Q4, Q5, Q8

# %%
# Get column index of questions

idx_Q1 = cons1_df.columns.get_loc(str([col for col in cons1_df if 'census methods' in str(col)][0]))
idx_Q4 = cons1_df.columns.get_loc(str([col for col in cons1_df if '4. 1. ' in str(col)][0]))
idx_Q5 = cons1_df.columns.get_loc(str([col for col in cons1_df if '5. 1.' in str(col)][0]))
idx_Q8 = cons1_df.columns.get_loc(str([col for col in cons1_df if '8.' in str(col)][0]))

# %%
# Checks
idx_Q1, idx_Q4, idx_Q5, idx_Q8
# Out:
# (39, 43, 45, 48)

# %%
# Calculate and save the Sentiment Score as new columns in the dataset

cons1_df.loc[:, ('Q1_Sentiment')] = get_sentiment_score(cons1_df, idx_Q1)
cons1_df.loc[:, ('Q4_Sentiment')] = get_sentiment_score(cons1_df, idx_Q4)
cons1_df.loc[:, ('Q5_Sentiment')] = get_sentiment_score(cons1_df, idx_Q5)
cons1_df.loc[:, ('Q8_Sentiment')] = get_sentiment_score(cons1_df, idx_Q8)

# %%
# Take a look at the result
cons1_df.iloc[:, [idx_Q1, -4, idx_Q4, -3, idx_Q5, -2, idx_Q8, -1]]
# Out:
# 0    1. What are your views of the different census methods described in the consultation document?Open-Ended Response  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Moving to a primarily online census: an inevit...
# 4     A regular full population census is absolutely...
# 5     Privacy is a clear concern with the whole coun...
# 6                                                   NaN
# 7     Neither is satisfactory, inevitably so given t...
# 8     Continuance of census once a decade with on-li...
# 9     •\tWhile a 10-year census has its uses for his...
# 10    The Research and Intelligence function within ...
# 11    The advantages and disadvantages of both optio...
# 12    1.\tThe administrative data plus survey option...
# 13    I believe we should continue with a census onc...
# 14                                                  NaN
# 15    As ardent family historians we consider that t...
# 16    I favour the once a decade method, like that c...
# 17    The savings from switching to a mostly online ...
# 18                                                  NaN
# 19    In collating our response we have sought a ran...
# 20    While there are attractions to both methods, t...
# 21    The RAC Foundation (Royal Automobile Club Foun...
# 22    I found the traditional census very useful and...
# 23    The proposed new approach based on administrat...
# 24    GfK is strongly in favour of Option A, the Onl...
# 25    It would be a shame to loose the continuity of...
# 26    Public Health Wales NHS Trust is firmly of the...
# 27                                                  NaN
# 28    Over the long term a series of snapshots at si...
# 29    Re: Document C1, section A2: I am commenting o...
# ...                                                 ...
# 1078  Admin burden on the individual which seems pre...
# 1079  A decennial Census is preferable because of th...
# 1080  I feel that a census once a decade is still th...
# 1081                                                NaN
# 1082  I'd prefer a primary census. What has come to ...
# 1083  I completed the 2011 census online and would e...
# 1084  I prefer it to be done  as the 2011 census.  N...
# 1085                                                NaN
# 1086                                                NaN
# 1087                                                NaN
# 1088                                                NaN
# 1089  The basic issue here is DATA PROTECTION. The i...
# 1090     We need a Census fit for purpose in modern age
# 1091                                                NaN
# 1092  The once a decade model is preferable. It prov...
# 1093                                                NaN
# 1094                                                NaN
# 1095  I favour the retention of the traditional cens...
# 1096                                                NaN
# 1097                                                NaN
# 1098                                                NaN
# 1099                                                NaN
# 1100  I favour the large annual compulsory survey wh...
# 1101                                                NaN
# 1102                                                NaN
# 1103                                                NaN
# 1104                                                NaN
# 1105  I feel that the survey carried out every ten y...
# 1106  Only a once a decade option will provide the a...
# 1107  There are major privacy concerns on using what...
#
# 0     Q1_Sentiment  \
# 0              NaN
# 1              NaN
# 2              NaN
# 3          -0.4585
# 4           0.9814
# 5           0.9648
# 6              NaN
# 7           0.1887
# 8          -0.0258
# 9           0.9879
# 10          0.9337
# 11          0.8657
# 12         -0.1513
# 13          0.2617
# 14             NaN
# 15          0.3818
# 16          0.6597
# 17         -0.1027
# 18             NaN
# 19          0.9987
# 20          0.9557
# 21          0.9239
# 22          0.9014
# 23          0.9552
# 24          0.7845
# 25         -0.8820
# 26          0.6948
# 27             NaN
# 28          0.4582
# 29          0.9008
# ...            ...
# 1078        0.0772
# 1079        0.7783
# 1080        0.6696
# 1081           NaN
# 1082       -0.4019
# 1083        0.1027
# 1084        0.4588
# 1085           NaN
# 1086           NaN
# 1087           NaN
# 1088           NaN
# 1089        0.8225
# 1090        0.3612
# 1091           NaN
# 1092        0.5984
# 1093           NaN
# 1094           NaN
# 1095        0.7043
# 1096           NaN
# 1097           NaN
# 1098           NaN
# 1099           NaN
# 1100        0.4404
# 1101           NaN
# 1102           NaN
# 1103           NaN
# 1104           NaN
# 1105        0.5709
# 1106        0.0000
# 1107        0.8683
#
# 0    4. What would the impact be if the most detailed statistics for very small geographic areas and small population groups were no longer available? High, medium, low or no impact? <b>4. 1. If you have answered high or medium impact, please give further information.</b>  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     It is important for the Census to provide data...
# 4     Would lose the ability to understand the local...
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8     Historic family data will no longer be availab...
# 9                                                   NaN
# 10    Losing details at LSOA level and below would b...
# 11                                                  NaN
# 12    1.\tMany agencies involved in the planning and...
# 13    We would loose data that would enable future g...
# 14                                                  NaN
# 15    The historical value of house-by-house data th...
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19    As indicated earlier, the loss of Output Area ...
# 20    Loss of detail in monitoring local health woul...
# 21    A lack of detailed statistics for very small a...
# 22    Mostly low impact I think.  As few people real...
# 23    Use of small area statistics is important in u...
# 24    The lack of small area data would lead to an i...
# 25    As previously stated we may be less able to re...
# 26    The loss of data for populations and subgroups...
# 27                                                  NaN
# 28    As has been proved beyond question the existen...
# 29                                                  NaN
# ...                                                 ...
# 1078  There would be a risk of reduced social inclus...
# 1079                                                NaN
# 1080  The basic feature of the census is to generate...
# 1081                                                NaN
# 1082                            Devil is in the detail.
# 1083  Large groups of immigrants settling in an area...
# 1084  It may not impact on the day to day use of the...
# 1085                                                NaN
# 1086                                                NaN
# 1087                                                NaN
# 1088                                                NaN
# 1089                                                NaN
# 1090                                                NaN
# 1091                                                NaN
# 1092  There is no other reliable data at this level ...
# 1093                                                NaN
# 1094                                                NaN
# 1095  It would have negative effects on all aspects ...
# 1096                                                NaN
# 1097                                                NaN
# 1098                                                NaN
# 1099                                                NaN
# 1100  Even in small areas and amongst small populati...
# 1101                                                NaN
# 1102                                                NaN
# 1103                                                NaN
# 1104                                                NaN
# 1105  I beleive that it is equally important to have...
# 1106  When the original census was introduced, the o...
# 1107  This is he point of his survey, it provides de...
#
# 0     Q4_Sentiment  \
# 0              NaN
# 1              NaN
# 2              NaN
# 3           0.6486
# 4           0.8360
# 5              NaN
# 6              NaN
# 7              NaN
# 8          -0.5267
# 9              NaN
# 10         -0.8807
# 11             NaN
# 12         -0.9830
# 13         -0.6808
# 14             NaN
# 15          0.3400
# 16             NaN
# 17             NaN
# 18             NaN
# 19         -0.9554
# 20         -0.7178
# 21         -0.1280
# 22         -0.4404
# 23         -0.3612
# 24          0.9832
# 25          0.0534
# 26          0.8720
# 27             NaN
# 28          0.3919
# 29             NaN
# ...            ...
# 1078       -0.2732
# 1079           NaN
# 1080        0.4588
# 1081           NaN
# 1082       -0.6597
# 1083       -0.2960
# 1084        0.0000
# 1085           NaN
# 1086           NaN
# 1087           NaN
# 1088           NaN
# 1089           NaN
# 1090           NaN
# 1091           NaN
# 1092        0.5574
# 1093           NaN
# 1094           NaN
# 1095       -0.5719
# 1096           NaN
# 1097           NaN
# 1098           NaN
# 1099           NaN
# 1100        0.3182
# 1101           NaN
# 1102           NaN
# 1103           NaN
# 1104           NaN
# 1105        0.5574
# 1106        0.5423
# 1107        0.0000
#
# 0    5. What would the additional benefit be if more frequent (i.e. annual) statistics about population characteristics were available for areas like local authorities and electoral wards? High, medium, low or no additional benefit?<b>5. 1. If you have answered high or medium impact, please give further information.</b>  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     Up to date statistics at postcode sector (or e...
# 4     It would allow the council to respond more eff...
# 5                                                   NaN
# 6                                                   NaN
# 7     Local authorities suffer from out of date cens...
# 8     Frequent statistics updates are needed by loca...
# 9     10-yearly information is now out-moded - the w...
# 10    For Oldham, Mid-Year Estimates (MYE) of popula...
# 11    It is difficult to access the potential benefi...
# 12    But the output proposed in Box B is nowhere ne...
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19    There would be addition benefit to us from bei...
# 20    Indicators to monitor  social deprivation and ...
# 21                                                  NaN
# 22    This would help monitor changes more frequentl...
# 23    More frequent statistics about populations for...
# 24    The recency of the data is valuable, and we wo...
# 25    More frequent statistics could enable more acc...
# 26    It is important to recognise that public bodie...
# 27                                                  NaN
# 28                                                  NaN
# 29    One could expect better tracking of circumstan...
# ...                                                 ...
# 1078  Impact on the citizen would be admin burden an...
# 1079                                                NaN
# 1080                                                NaN
# 1081                                                NaN
# 1082  Trends can happen quite quickly. For example i...
# 1083  As above more data enables better planning and...
# 1084                          More accurate information
# 1085                                                NaN
# 1086                                                NaN
# 1087                                                NaN
# 1088                                                NaN
# 1089                                                NaN
# 1090  Better targeting of tax payer funded intervent...
# 1091                                                NaN
# 1092  It would provide a more up-to-date and reliabl...
# 1093                                                NaN
# 1094                                                NaN
# 1095                                                NaN
# 1096                                                NaN
# 1097                                                NaN
# 1098                                                NaN
# 1099                                                NaN
# 1100  Would of course be very useful but cost and co...
# 1101                                                NaN
# 1102                                                NaN
# 1103                                                NaN
# 1104                                                NaN
# 1105  I agree that annual statistics if collected an...
# 1106                                                NaN
# 1107                                                NaN
#
# 0     Q5_Sentiment  \
# 0              NaN
# 1              NaN
# 2              NaN
# 3           0.4404
# 4           0.9651
# 5              NaN
# 6              NaN
# 7          -0.5574
# 8          -0.9020
# 9           0.8004
# 10          0.7207
# 11          0.9521
# 12          0.5775
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19          0.6831
# 20         -0.1280
# 21             NaN
# 22          0.6208
# 23          0.6486
# 24          0.8934
# 25         -0.6056
# 26          0.8830
# 27             NaN
# 28             NaN
# 29          0.4404
# ...            ...
# 1078        0.2632
# 1079           NaN
# 1080           NaN
# 1081           NaN
# 1082        0.0000
# 1083        0.2398
# 1084        0.0000
# 1085           NaN
# 1086           NaN
# 1087           NaN
# 1088           NaN
# 1089           NaN
# 1090        0.1010
# 1091           NaN
# 1092        0.3321
# 1093           NaN
# 1094           NaN
# 1095           NaN
# 1096           NaN
# 1097           NaN
# 1098           NaN
# 1099           NaN
# 1100        0.2724
# 1101           NaN
# 1102           NaN
# 1103           NaN
# 1104           NaN
# 1105       -0.1027
# 1106           NaN
# 1107           NaN
#
# 0    8. What are your views of the risks of each census approach and how they might be managed?Open-Ended Response  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     It is essential that any changes to census met...
# 4     Measures must be put in place to ensure that n...
# 5     There are some users of the census who place a...
# 6                                                   NaN
# 7     The first approach simply perpetuates existing...
# 8                                                   NaN
# 9     The 10-year census method is out-dated and the...
# 10    Response rates:  The approach taken by ONS for...
# 11                                                  NaN
# 12                                     See answer to 1.
# 13                                                  NaN
# 14                                                  NaN
# 15    Full Census - A good majority of householders ...
# 16                                                  NaN
# 17    Changing from the existing system is highly ri...
# 18                                                  NaN
# 19    We have identified these risks in addition to ...
# 20             These were described in my answers to Q1
# 21    The Foundation is concerned by the lack of dis...
# 22    I think these were well outlined in the consul...
# 23    As previously noted, a dual-running approach a...
# 24    The risks of Option B in particular are the la...
# 25    Online – non-response bias for those without a...
# 26    A universal Census with online as the primary ...
# 27                                                  NaN
# 28    Refusal to participate reduces the value. Some...
# 29                                                  NaN
# ...                                                 ...
# 1078  Each aaproach must embrace electronic and soci...
# 1079  The major risk of a decennial Census is that i...
# 1080                                                NaN
# 1081                                                NaN
# 1082  The main risk is that collating from a variety...
# 1083  Lack of an encapsulated timeframe as in the 10...
# 1084                                                NaN
# 1085                                                NaN
# 1086                                                NaN
# 1087                                                NaN
# 1088                                                NaN
# 1089  NEVER collect data which is not ABSOLUTELY ESS...
# 1090               Seems to be clear what the risks are
# 1091                                                NaN
# 1092                                                NaN
# 1093                                                NaN
# 1094                                                NaN
# 1095  I think the risks - in terms of reliability an...
# 1096                                                NaN
# 1097                                                NaN
# 1098                                                NaN
# 1099                                                NaN
# 1100                                                N/a
# 1101                                                NaN
# 1102                                                NaN
# 1103                                                NaN
# 1104                                                NaN
# 1105  There is evidence that the compulsion to compl...
# 1106                                                NaN
# 1107  Private data should remain private, keep the e...
#
# 0     Q8_Sentiment
# 0              NaN
# 1              NaN
# 2              NaN
# 3           0.7596
# 4           0.2500
# 5           0.9619
# 6              NaN
# 7           0.4939
# 8              NaN
# 9           0.5565
# 10         -0.7707
# 11             NaN
# 12          0.0000
# 13             NaN
# 14             NaN
# 15          0.9114
# 16             NaN
# 17         -0.2716
# 18             NaN
# 19          0.9846
# 20          0.0000
# 21         -0.5789
# 22          0.7865
# 23         -0.2732
# 24          0.9531
# 25          0.7346
# 26          0.9205
# 27             NaN
# 28          0.2263
# 29             NaN
# ...            ...
# 1078        0.7717
# 1079       -0.2028
# 1080           NaN
# 1081           NaN
# 1082        0.2632
# 1083        0.2144
# 1084           NaN
# 1085           NaN
# 1086           NaN
# 1087           NaN
# 1088           NaN
# 1089        0.3182
# 1090        0.1280
# 1091           NaN
# 1092           NaN
# 1093           NaN
# 1094           NaN
# 1095        0.1027
# 1096           NaN
# 1097           NaN
# 1098           NaN
# 1099           NaN
# 1100        0.0000
# 1101           NaN
# 1102           NaN
# 1103           NaN
# 1104           NaN
# 1105       -0.5859
# 1106           NaN
# 1107       -0.5719
#
# [1108 rows x 8 columns]

# %%
# Summary satistics
cons1_df.iloc[:, [idx_Q1, -4, idx_Q4, -3, idx_Q5, -2, idx_Q8, -1]].describe()
# Out:
# 0      Q1_Sentiment  Q4_Sentiment  Q5_Sentiment  Q8_Sentiment
# count    736.000000    523.000000    396.000000    490.000000
# mean       0.388333      0.073410      0.338060      0.092375
# std        0.523643      0.515057      0.425649      0.575458
# min       -0.981700     -0.983000     -0.904200     -0.969100
# 25%        0.000000     -0.318200      0.000000     -0.361200
# 50%        0.493900      0.000000      0.440400      0.000000
# 75%        0.866425      0.440400      0.690275      0.633900
# max        0.999800      0.999900      0.995400      0.998800
